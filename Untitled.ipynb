# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
df1=sns.load_dataset('iris')
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df2=sns.load_dataset('titanic')

# %%
conditions=[
    (df1.species=='setosa'), 
    (df1.species=='versicolor'),
     (df1.species=='virginica')
]
values=(1,2,3)
df1['new']=np.select(conditions,values)

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  new
# 0           5.1          3.5           1.4          0.2  setosa    1
# 1           4.9          3.0           1.4          0.2  setosa    1
# 2           4.7          3.2           1.3          0.2  setosa    1
# 3           4.6          3.1           1.5          0.2  setosa    1
# 4           5.0          3.6           1.4          0.2  setosa    1

# %%
df1.groupby('species').sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width  new       n2
# species
# setosa             250.3        171.4          73.1         12.3   50  1259.09
# versicolor         296.8        138.5         213.0         66.3  100  1774.86
# virginica          329.4        148.7         277.6        101.3  150  2189.90

# %%
df1['n2']=df1['sepal_length'].apply(lambda x:x**2)

# %%
df1.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# new              3
# n2              35
# dtype: int64

# %%
df1.iloc[0][0:4].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(df1)
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='new', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='n2', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='new', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='n2', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
# ...

# %%
df1.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# new               int32
# n2              float64
# dtype: object

# %%
df1[df1.dtypes[df1.dtypes=='object'].index]
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
df2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
a=np.where(df2.isnull()==True)

# %%
df2.iloc[a]
# Out:
#     deck deck deck   age deck deck deck deck deck deck  ... deck deck deck  \
# 0    NaN  NaN  NaN  22.0  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 2    NaN  NaN  NaN  26.0  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 4    NaN  NaN  NaN  35.0  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 5    NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 5    NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# ..   ...  ...  ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 885  NaN  NaN  NaN  39.0  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 886  NaN  NaN  NaN  27.0  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 888  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 888  NaN  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 890  NaN  NaN  NaN  32.0  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#     deck deck deck deck   age deck deck
# ...
